# %% [markdown]
# <div dir="rtl">
#
# ### מלאו את הקובץ ושלחו לרז
#
#    - **ניתן למלא באנגלית או עברית**
#    - **מומלץ להשתמש בהמשך באותו הקובץ להגשת הפרויקט (מיחקו את התא הזה)**
#    - **הקפידו למלא טקסט בשדות מסוג מארק-דאון וקוד בשדות מסוג קוד (אחרת ירדו לכם נקודות)**
#
# ###   מלאו את כל הסעיפים. הניקוד ינתן באופן הבא:
# - **שם הפרויקט (3-4 מילים) - 5 נקודות**
# - **שמות מלאים של כל חברי הצוות, ללא ת.ז - 5 נקודות**
# - **תיאור הפרויקט (3-4 משפטים) - 10 נקודות**
# - **קישור למקור ממנו הורדתם את הנתונים - 10 נקודות**
# - **קריאת הקובץ מהגיטהאב שלכם - 10 נקודות**
# - **הסבר על מקור הנתונים - 10 נקודות**
# - **תיאור קצר של הדאטה בעזרת הפקודות שנלמדו בקורס - 20 נקודות**
# - **שלוש שאלות ראשוניות של דברים שהיה מעניין אתכם להוציא מהקובץ - 30 נקודות**
# #### בהצלחה !
# </div>

# %% [markdown]
# # Project Name: `Student Insomnia and Educational Outcomes`

# %% [markdown]
# ### Project team members:
# - `Yogev Shabtay`
# - `Tomer Stupko`

# %% [markdown]
# ### Project number: 5

# %% [markdown]
# ### Project description:
# `בפרוייקט זה נבחן את הקשר בין שעות השינה הממוצעות של סטודנטים ואיכות השינה שלהם לבין הביצועים האקדמיים שלהם. בנוסף, נבדוק את הקשר בין הרגלים שונים לבין איכות השינה. המטרה שלנו היא לבדוק איך ניתן לשפר את איכות השינה במטרה לשפר הישגים אקדמיים.`

# %% [markdown]
# ### Link to the data:
# https://data.mendeley.com/datasets/5mvrx4v62z/2

# %% [markdown]
# ### Explain the data source:
# `The data was collected through an online survey administered via Google Forms in Oct-Nov 2024. Respondents were asked to provide insights into their sleep behaviors and the effects on their academic and daily activities.`

# %% [markdown]
# ----

# %% [markdown]
# #### Read you file from Github:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("https://raw.githubusercontent.com/TomerStupko/data-analysis-project/refs/heads/main/Student%20Insomnia%20and%20Educational%20Outcomes%20Dataset.csv")
df
# Out:
#                Timestamp 1. What is your year of study?  \
# 0    10/24/2024 16:51:15               Graduate student
# 1    10/24/2024 16:51:51                     Third year
# 2    10/24/2024 16:52:21                     First year
# 3    10/24/2024 16:53:00                     Third year
# 4    10/24/2024 16:53:25               Graduate student
# ..                   ...                            ...
# 786     11/06/2024 19:10                     Third year
# 787     11/06/2024 19:11               Graduate student
# 788     11/06/2024 19:12               Graduate student
# 789     11/06/2024 19:14               Graduate student
# 790     11/06/2024 19:15                     Third year
#
#     2. What is your gender?  \
# 0                      Male
# 1                      Male
# 2                    Female
# 3                      Male
# 4                      Male
# ..                      ...
# 786                    Male
# 787                    Male
# 788                    Male
# 789                    Male
# 790                    Male
#
#     3. How often do you have difficulty falling asleep at night?   \
# 0                             Often (5-6 times a week)
# 1                             Often (5-6 times a week)
# 2                         Sometimes (3-4 times a week)
# 3                             Often (5-6 times a week)
# 4                             Often (5-6 times a week)
# ..                                                 ...
# 786                                        Every night
# 787                           Often (5-6 times a week)
# 788                                        Every night
# 789                                        Every night
# 790                                        Every night
#
#     4. On average, how many hours of sleep do you get on a typical day?  \
# 0                                            7-8 hours
# 1                                            7-8 hours
# 2                                            7-8 hours
# 3                                    More than 8 hours
# 4                                            7-8 hours
# ..                                                 ...
# 786                                  More than 8 hours
# 787                                  More than 8 hours
# 788                                  More than 8 hours
# 789                                          7-8 hours
# 790                                  More than 8 hours
#
#     5. How often do you wake up during the night and have trouble falling back asleep?  \
# 0                             Often (5-6 times a week)
# 1                             Often (5-6 times a week)
# 2                         Sometimes (3-4 times a week)
# 3                         Sometimes (3-4 times a week)
# 4                             Often (5-6 times a week)
# ..                                                 ...
# 786                                        Every night
# 787                           Often (5-6 times a week)
# 788                           Often (5-6 times a week)
# 789                                        Every night
# 790                           Often (5-6 times a week)
#
#     6. How would you rate the overall quality of your sleep?  \
# 0                                                 Good
# 1                                                 Good
# 2                                                 Good
# 3                                                 Poor
# 4                                            Very good
# ..                                                 ...
# 786                                          Very poor
# 787                                               Poor
# 788                                          Very poor
# 789                                            Average
# 790                                               Poor
#
#     7. How often do you experience difficulty concentrating during lectures or studying due to lack of sleep?  \
# 0                                            Sometimes
# 1                                                Often
# 2                                                Often
# 3                                                Often
# 4                                               Always
# ..                                                 ...
# 786                                             Always
# 787                                              Often
# 788                                             Always
# 789                                              Often
# 790                                              Often
#
#     8. How often do you feel fatigued during the day, affecting your ability to study or attend classes?  \
# 0                                                Often
# 1                                            Sometimes
# 2                                                Often
# 3                                                Often
# 4                                            Sometimes
# ..                                                 ...
# 786                                              Often
# 787                                             Always
# 788                                              Often
# 789                                              Often
# 790                                              Often
#
#     9. How often do you miss or skip classes due to sleep-related issues (e.g., insomnia, feeling tired)?  \
# 0                             Often (3-4 times a week)
# 1                         Sometimes (1-2 times a week)
# 2                         Sometimes (1-2 times a week)
# 3                           Rarely (1-2 times a month)
# 4                         Sometimes (1-2 times a week)
# ..                                                 ...
# 786                           Often (3-4 times a week)
# 787                           Often (3-4 times a week)
# 788                                             Always
# 789                           Often (3-4 times a week)
# 790                           Often (3-4 times a week)
#
#     10. How would you describe the impact of insufficient sleep on your ability to complete assignments and meet deadlines?  \
# 0                                      Moderate impact
# 1                                         Major impact
# 2                                         Major impact
# 3                                         Minor impact
# 4                                      Moderate impact
# ..                                                 ...
# 786                                       Major impact
# 787                                      Severe impact
# 788                                      Severe impact
# 789                                      Severe impact
# 790                                      Severe impact
#
#     11. How often do you use electronic devices (e.g., phone, computer) before going to sleep?  \
# 0                             Often (5-6 times a week)
# 1                         Sometimes (3-4 times a week)
# 2                             Often (5-6 times a week)
# 3                         Sometimes (3-4 times a week)
# 4                         Sometimes (3-4 times a week)
# ..                                                 ...
# 786                                        Every night
# 787                                        Every night
# 788                           Often (5-6 times a week)
# 789                                        Every night
# 790                           Often (5-6 times a week)
#
#     12. How often do you consume caffeine (coffee, energy drinks) to stay awake or alert?  \
# 0                            Rarely (1-2 times a week)
# 1                         Sometimes (3-4 times a week)
# 2                             Often (5-6 times a week)
# 3                         Sometimes (3-4 times a week)
# 4                         Sometimes (3-4 times a week)
# ..                                                 ...
# 786                           Often (5-6 times a week)
# 787                                          Every day
# 788                           Often (5-6 times a week)
# 789                                          Every day
# 790                                          Every day
#
#     13. How often do you engage in physical activity or exercise?  \
# 0                         Sometimes (3-4 times a week)
# 1                         Sometimes (3-4 times a week)
# 2                             Often (5-6 times a week)
# 3                                            Every day
# 4                             Often (5-6 times a week)
# ..                                                 ...
# 786                                          Every day
# 787                                          Every day
# 788                                          Every day
# 789                                          Every day
# 790                           Often (5-6 times a week)
#
#     14. How would you describe your stress levels related to academic workload?  \
# 0                                          High stress
# 1                                           Low stress
# 2                                          High stress
# 3                                Extremely high stress
# 4                                           Low stress
# ..                                                 ...
# 786                              Extremely high stress
# 787                              Extremely high stress
# 788                              Extremely high stress
# 789                                        High stress
# 790                              Extremely high stress
#
#     15. How would you rate your overall academic performance (GPA or grades) in the past semester?
# 0                                              Average
# 1                                                 Good
# 2                                        Below Average
# 3                                            Excellent
# 4                                              Average
# ..                                                 ...
# 786                                            Average
# 787                                               Poor
# 788                                               Poor
# 789                                      Below Average
# 790                                               Poor
#
# [791 rows x 16 columns]

# %% [markdown]
# #### Describe the data
# * How many rows?
# * How many columns?
# * How many numeric columns? (not including numerical identifiers - numbers that uniquely define the row)
# * How many categorical columns? (not including string identifiers -  values that uniquely define the row)

# %%
len(df)
# Out:
# 791

# %%
len(df.columns)
# Out:
# 16

# %%
df.select_dtypes(include='number').shape[1]
# Out:
# 0

# %%
len(df.describe(include = 'object').columns)
# Out:
# 16

# %% [markdown]
# #### Write three questions you would like to answer using this data

# %% [markdown]
# 1. `?האם קיים קשר בין שעות שינה ממוצעות לבין הישגים אקדמיים`

# %% [markdown]
# 2. `?כיצד שימוש במסכים לפני השינה משפיע על איכות השינה`

# %% [markdown]
# 3. `?האם חוסר בשעות שינה מגביר את הלחץ בלימודים`

# %% [markdown]
# <div style="background-color: #f0f0f0; padding: 10px; border-radius: 5px;">
#   <span style="color: red;"><strong>— Do not proceed beyond this point. This is for the next steps, do not fill in —</strong></span>
# </div>

# %% [markdown]
# ---
# ### <span style="color:green"> Observation 1:</span>
#
# >
# >
# >
# >
#
#
# ---

# %% [markdown]
# ---
# ### <span style="color:green"> Observation 2:</span>
#
# >
# >
# >
# >
#
#
# ---

# %% [markdown]
# ---
# ### <span style="color:green"> Observation 3:</span>
#
# >
# >
# >
# >
#
#
# ---

# %% [markdown]
# ---
# ### <span style="color:green"> Summary</span>
#
# > Anything you'd like to say - your conclusions, summary, how hard you worked etc.
# >
# >
# >
#
#
# ---
